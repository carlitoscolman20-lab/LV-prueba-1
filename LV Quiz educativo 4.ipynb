# %%
import tkinter as tk
from tkinter import messagebox
import random

# Banco de preguntas con dificultad
preguntas_totales = [
    {"pregunta": "¿Cuál es el planeta más grande del sistema solar?",
     "opciones": ["Tierra", "Júpiter", "Saturno", "Neptuno"], "respuesta": "Júpiter", "dificultad": "Fácil"},
    {"pregunta": "¿Cuánto es 8 x 8?",
     "opciones": ["56", "64", "72", "60"], "respuesta": "64", "dificultad": "Fácil"},
    {"pregunta": "¿Quién pintó la Mona Lisa?",
     "opciones": ["Leonardo da Vinci", "Picasso", "Van Gogh", "Miguel Ángel"], "respuesta": "Leonardo da Vinci", "dificultad": "Fácil"},
    {"pregunta": "¿En qué continente está Egipto?",
     "opciones": ["Asia", "África", "Europa", "Oceanía"], "respuesta": "África", "dificultad": "Fácil"},
    {"pregunta": "¿Cuántos lados tiene un hexágono?",
     "opciones": ["5", "6", "8", "7"], "respuesta": "6", "dificultad": "Fácil"},
    {"pregunta": "¿Qué gas respiramos para vivir?",
     "opciones": ["Nitrógeno", "Dióxido de carbono", "Oxígeno", "Helio"], "respuesta": "Oxígeno", "dificultad": "Fácil"},
    {"pregunta": "¿Cuál es el río más largo del mundo?",
     "opciones": ["Nilo", "Amazonas", "Yangtsé", "Misisipi"], "respuesta": "Amazonas", "dificultad": "Medio"},
    {"pregunta": "¿Cuál es la capital de Francia?",
     "opciones": ["Madrid", "Roma", "París", "Londres"], "respuesta": "París", "dificultad": "Fácil"},
    {"pregunta": "¿Qué instrumento mide la temperatura?",
     "opciones": ["Barómetro", "Termómetro", "Anemómetro", "Pluviómetro"], "respuesta": "Termómetro", "dificultad": "Fácil"},
    {"pregunta": "¿Qué color tiene el cielo despejado?",
     "opciones": ["Verde", "Azul", "Rojo", "Blanco"], "respuesta": "Azul", "dificultad": "Fácil"},
    {"pregunta": "¿Cuál es el océano más grande del mundo?",
     "opciones": ["Atlántico", "Pacífico", "Índico", "Ártico"], "respuesta": "Pacífico", "dificultad": "Fácil"},
    {"pregunta": "¿Qué número romano representa el 10?",
     "opciones": ["V", "X", "L", "C"], "respuesta": "X", "dificultad": "Fácil"},
    {"pregunta": "¿Qué planeta es conocido como el planeta rojo?",
     "opciones": ["Venus", "Marte", "Júpiter", "Saturno"], "respuesta": "Marte", "dificultad": "Fácil"},
    {"pregunta": "¿Qué órgano bombea la sangre?",
     "opciones": ["Pulmones", "Corazón", "Cerebro", "Hígado"], "respuesta": "Corazón", "dificultad": "Fácil"},
    {"pregunta": "¿Qué idioma se habla en Brasil?",
     "opciones": ["Español", "Portugués", "Francés", "Inglés"], "respuesta": "Portugués", "dificultad": "Fácil"},
    {"pregunta": "¿Cuál es el país más grande del mundo?",
     "opciones": ["China", "EE.UU.", "Rusia", "Canadá"], "respuesta": "Rusia", "dificultad": "Medio"},
    {"pregunta": "¿Cuántos continentes hay en el planeta?",
     "opciones": ["5", "6", "7", "8"], "respuesta": "7", "dificultad": "Fácil"},
    {"pregunta": "¿Qué instrumento tiene teclas blancas y negras?",
     "opciones": ["Violín", "Piano", "Guitarra", "Flauta"], "respuesta": "Piano", "dificultad": "Fácil"},
    {"pregunta": "¿Qué figura tiene cuatro lados iguales?",
     "opciones": ["Rectángulo", "Cuadrado", "Rombo", "Trapecio"], "respuesta": "Cuadrado", "dificultad": "Fácil"},
    {"pregunta": "¿Qué planeta tiene anillos visibles?",
     "opciones": ["Urano", "Saturno", "Neptuno", "Venus"], "respuesta": "Saturno", "dificultad": "Medio"},
    {"pregunta": "¿Quién escribió 'Don Quijote de la Mancha'?",
     "opciones": ["Cervantes", "García Márquez", "Borges", "Shakespeare"], "respuesta": "Cervantes", "dificultad": "Fácil"},
    {"pregunta": "¿Qué gas utilizan las plantas para hacer fotosíntesis?",
     "opciones": ["Oxígeno", "Dióxido de carbono", "Nitrógeno", "Helio"], "respuesta": "Dióxido de carbono", "dificultad": "Fácil"},
    {"pregunta": "¿Qué deporte se juega con una pelota y una red alta?",
     "opciones": ["Fútbol", "Vóley", "Tenis", "Básquet"], "respuesta": "Vóley", "dificultad": "Fácil"},
    {"pregunta": "¿Cuál es el animal más grande del planeta?",
     "opciones": ["Elefante", "Ballena azul", "Tiburón blanco", "Rinoceronte"], "respuesta": "Ballena azul", "dificultad": "Medio"},
    {"pregunta": "¿Qué número sigue al 99?",
     "opciones": ["100", "101", "98", "102"], "respuesta": "100", "dificultad": "Fácil"},

    # Nuevas preguntas
    {"pregunta": "¿Quién descubrió la gravedad?", "opciones": ["Newton", "Einstein", "Galileo", "Tesla"],
     "respuesta": "Newton", "dificultad": "Medio"},
    {"pregunta": "¿Cuál es la capital de Mongolia?", "opciones": ["Ulan Bator", "Beijing", "Seúl", "Bangkok"],
     "respuesta": "Ulan Bator", "dificultad": "Difícil"},
    {"pregunta": "¿Qué instrumento mide la presión atmosférica?", "opciones": ["Barómetro", "Termómetro", "Anemómetro", "Pluviómetro"],
     "respuesta": "Barómetro", "dificultad": "Medio"},
    {"pregunta": "¿Cuál es la fórmula química del agua?", "opciones": ["H2O", "CO2", "NaCl", "O2"],
     "respuesta": "H2O", "dificultad": "Fácil"},
    {"pregunta": "¿Quién escribió 'La Odisea'?", "opciones": ["Homero", "Sófocles", "Platón", "Aristóteles"],
     "respuesta": "Homero", "dificultad": "Medio"},
    {"pregunta": "¿Qué planeta tiene la mayor cantidad de lunas conocidas?", "opciones": ["Júpiter", "Saturno", "Urano", "Neptuno"],
     "respuesta": "Saturno", "dificultad": "Difícil"},
    {"pregunta": "¿Cuál es el metal más ligero?", "opciones": ["Aluminio", "Litio", "Hierro", "Plomo"],
     "respuesta": "Litio", "dificultad": "Medio"},
    {"pregunta": "¿Qué idioma tiene más hablantes nativos?", "opciones": ["Español", "Inglés", "Chino mandarín", "Hindi"],
     "respuesta": "Chino mandarín", "dificultad": "Fácil"},
    {"pregunta": "¿Quién es conocido como el padre de la computación?", "opciones": ["Charles Babbage", "Alan Turing", "Steve Jobs", "Bill Gates"],
     "respuesta": "Charles Babbage", "dificultad": "Difícil"},
    {"pregunta": "¿Qué ciudad tiene la Torre Eiffel?", "opciones": ["París", "Londres", "Roma", "Madrid"],
     "respuesta": "París", "dificultad": "Fácil"},
    {"pregunta": "¿Qué gas llena los globos aerostáticos?", "opciones": ["Oxígeno", "Helio", "Nitrógeno", "Dióxido de carbono"],
     "respuesta": "Helio", "dificultad": "Medio"},
    {"pregunta": "¿Qué continente tiene más países?", "opciones": ["África", "Europa", "Asia", "América"],
     "respuesta": "África", "dificultad": "Medio"},
    {"pregunta": "¿Qué océano está al este de África?", "opciones": ["Atlántico", "Pacífico", "Índico", "Ártico"],
     "respuesta": "Índico", "dificultad": "Medio"},
    {"pregunta": "¿Qué mineral es el más duro?", "opciones": ["Diamante", "Cuarzo", "Oro", "Hierro"],
     "respuesta": "Diamante", "dificultad": "Medio"},
    {"pregunta": "¿Qué planeta tiene el día más largo?", "opciones": ["Venus", "Mercurio", "Marte", "Júpiter"],
     "respuesta": "Venus", "dificultad": "Difícil"},
    {"pregunta": "¿Quién inventó la bombilla?", "opciones": ["Edison", "Tesla", "Volta", "Newton"],
     "respuesta": "Edison", "dificultad": "Fácil"},
]

# Variables globales
preguntas = []
indice_pregunta = 0
respuestas_usuario = []

# Funciones del Quiz
def iniciar_quiz():
    global preguntas, indice_pregunta, respuestas_usuario
    indice_pregunta = 0
    respuestas_usuario = []

    dif = dificultad_seleccionada.get()
    preguntas_filtradas = [p for p in preguntas_totales if p["dificultad"] == dif]
    preguntas = random.sample(preguntas_filtradas, min(10, len(preguntas_filtradas)))

    frame_inicio.pack_forget()
    frame_pregunta.pack(pady=30)
    btn_siguiente.pack(pady=20)
    mostrar_pregunta()


def siguiente_pregunta():
    global indice_pregunta

    seleccion = var_respuesta.get()
    if seleccion == "":
        messagebox.showwarning("Atención", "Debes seleccionar una respuesta antes de continuar.")
        return

    respuestas_usuario.append(seleccion)
    indice_pregunta += 1

    if indice_pregunta < len(preguntas):
        mostrar_pregunta()
    else:
        mostrar_resultados()


def mostrar_pregunta():
    var_respuesta.set("")
    lbl_pregunta.config(
        text=f"Pregunta {indice_pregunta+1} de {len(preguntas)}:\n\n{preguntas[indice_pregunta]['pregunta']}")
    for i, opcion in enumerate(preguntas[indice_pregunta]["opciones"]):
        botones_opciones[i].config(text=opcion, value=opcion)


def mostrar_resultados():
    frame_pregunta.pack_forget()
    btn_siguiente.pack_forget()

    aciertos = sum(respuestas_usuario[i] == p["respuesta"] for i, p in enumerate(preguntas))

    frame_resultado.pack(pady=20)
    lbl_resumen.config(text=f"Tu puntaje final: {aciertos} / {len(preguntas)}\n")

    texto_resultado = ""
    for i, p in enumerate(preguntas):
        correcta = p["respuesta"]
        elegida = respuestas_usuario[i]
        estado = "✅ Correcta" if elegida == correcta else f"❌ Incorrecta (Correcta: {correcta})"
        texto_resultado += f"{i+1}. {p['pregunta']}\nTu respuesta: {elegida}\n{estado}\n\n"

    txt_resultados.config(state="normal")
    txt_resultados.delete("1.0", "end")
    txt_resultados.insert("1.0", texto_resultado)
    txt_resultados.config(state="disabled")


def reiniciar_quiz():
    frame_resultado.pack_forget()
    iniciar_quiz()


# Interfaz gráfica
ventana = tk.Tk()
ventana.title("Quiz Educativo Básico")
ventana.geometry("600x700")
ventana.config(bg="#E6F7FF")

# -------- Pantalla de inicio --------
frame_inicio = tk.Frame(ventana, bg="#E6F7FF")
frame_inicio.pack(expand=True)

lbl_titulo = tk.Label(frame_inicio, text=" Quiz Educativo Básico", font=("Arial", 22, "bold"),
                      bg="#007ACC", fg="white", pady=10)
lbl_titulo.pack(fill="x")

lbl_intro = tk.Label(frame_inicio,
                     text="Bienvenido al Quiz Educativo Básico.\n\nResponderás 10 preguntas al azar según la dificultad seleccionada.\nAl final verás tus resultados.",
                     font=("Arial", 13), bg="#E6F7FF", fg="#333", justify="center")
lbl_intro.pack(pady=20)

dificultad_seleccionada = tk.StringVar(value="Fácil")
lbl_dificultad = tk.Label(frame_inicio, text="Selecciona dificultad:", font=("Arial", 13), bg="#E6F7FF")
lbl_dificultad.pack(pady=5)
for dif in ["Fácil", "Medio", "Difícil"]:
    rb = tk.Radiobutton(frame_inicio, text=dif, variable=dificultad_seleccionada, value=dif,
                        font=("Arial", 12), bg="#E6F7FF")
    rb.pack()

btn_comenzar = tk.Button(frame_inicio, text="Comenzar Quiz", command=iniciar_quiz,
                         bg="#007ACC", fg="white", font=("Arial", 14, "bold"), width=15)
btn_comenzar.pack(pady=20)

# -------- Pantalla de preguntas --------
frame_pregunta = tk.Frame(ventana, bg="#E6F7FF")

lbl_pregunta = tk.Label(frame_pregunta, text="", font=("Arial", 14, "bold"),
                        wraplength=500, bg="#E6F7FF", fg="#333")
lbl_pregunta.pack(pady=10)

var_respuesta = tk.StringVar()
botones_opciones = []
for i in range(4):
    rb = tk.Radiobutton(frame_pregunta, text="", variable=var_respuesta, value="",
                        font=("Arial", 12), bg="#E6F7FF", anchor="w", padx=20)
    rb.pack(fill="x", pady=3)
    botones_opciones.append(rb)

btn_siguiente = tk.Button(ventana, text="Siguiente ➜", command=siguiente_pregunta,
                          bg="#007ACC", fg="white", font=("Arial", 12, "bold"), width=15)

# -------- Pantalla de resultados --------
frame_resultado = tk.Frame(ventana, bg="#E6F7FF")

lbl_resumen = tk.Label(frame_resultado, text="", font=("Arial", 16, "bold"), bg="#E6F7FF", fg="#333")
lbl_resumen.pack(pady=10)

txt_resultados = tk.Text(frame_resultado, width=70, height=20, wrap="word",
                         font=("Arial", 11), bg="white", fg="#333")
txt_resultados.pack(pady=10)
txt_resultados.config(state="disabled")

btn_reintentar = tk.Button(frame_resultado, text="🔁 Reintentar", command=reiniciar_quiz,
                           bg="#2E8B57", fg="white", font=("Arial", 12, "bold"), width=12)
btn_reintentar.pack(pady=5)

btn_salir = tk.Button(frame_resultado, text="Salir", command=ventana.destroy,
                      bg="#B22222", fg="white", font=("Arial", 12, "bold"), width=12)
btn_salir.pack(pady=5)

ventana.mainloop()
